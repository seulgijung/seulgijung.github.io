# %%
import pandas as pd
pd.read_csv('centralsnow.csv')
df = pd.read_csv('centralsnow.csv')
df
# Out:
#    SEASON  NOV   DEC   JAN   FEB   MAR  APR
# 0    2015  0.0   0.0  27.9   4.0   0.9  0.0
# 1    2016  0.0   3.2   7.9   9.4   9.7  0.0
# 2    2017  0.0   7.7  11.2   4.9  11.6  5.5
# 3    2018  6.4   0.0   1.1   2.6  10.4  0.0
# 4    2019  0.0   2.5   2.3   0.0   0.0  0.0
# 5    2020  0.0  10.5   2.1  26.0   0.0  0.0
# 6    2021  0.0   0.2  15.3   2.0   0.4  0.0
# 7    2022  0.0   0.0   0.0   2.2   0.1  0.0
# 8    2023  0.0   0.0   2.3   5.2   0.0  0.0
# 9    2024  0.0   2.8   3.0   7.1   0.0  0.0

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df_year.plot(x='year', y='count', kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.style.use('fivethirtyeight')
# ----> 3 df_year.plot(x='year', y='count', kind='bar')
#
# NameError: name 'df_year' is not defined

# %%
print(3/4)
# Out:
# 0.75
